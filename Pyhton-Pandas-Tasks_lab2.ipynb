# %%
# create a Python class with a constructor and functions of all access specifiers each.
# Inherit a subclass from the above created class, initiate its constructor that also initiates the parent class constructor.
# Add a function in this subclass

class labs:
    _questions = 5
    __questions_answered = 0
    def __init__(self,lab_name,lab_number,lab_description):
        self.lab_name = lab_name
        self.lab_number = lab_number
        self.lab_description = lab_description
    def __display1(self):
        print(f"Lab Name: {self.lab_name} \nLab Number: {self.lab_number} \nLab Description: {self.lab_description}")

class department(labs):
    def __init__(self,lab_name,lab_number,lab_description,department_name):
        super().__init__(lab_name,lab_number,lab_description)
        self.department_name = department_name
    def _display2(self):
        print(f"Department Name: {self.department_name} \nLab Name: {self.lab_name} \nLab Number: {self.lab_number} \nLab Description: {self.lab_description}")

# %%
# Create an object of parent class and call its functions
# Create an object of child class and try accessing child functions as well as parent class functions.
lab1 = labs("lab1","1","pandas and numpy")
# lab1._display1() # This will not work as _display1 is private
lab2 = department("lab2","2","sklearn","AI")
lab2._display2()
# Out:
# Department Name: AI
# Lab Name: lab2
# Lab Number: 2
# Lab Description: sklearn

# %%
# Use enumerate in a scenario of your own choice
for i,j in enumerate(["a","b","c"],1):
    print(i,j)
# Out:
# 1 a
# 2 b
# 3 c

# %%
# Given a list of strings, return the count of the number of strings where the string length is 2 or more and the first and last chars of the string are the same.

def string_match(words):
    count = 0
    for i in words:
        if len(i)>=2 and i[0]==i[-1]:
            count+=1
    return count

print(string_match(["mango","apple","aba"]))
# Out:
# 1

# %%
# Given a list of strings, return a list with the strings in sorted order, except group all the strings that begin with &#39;x&#39; first.

def order(words):
    x = []
    y = []
    for i in words:
        if i[0]=="x":
            x.append(i)
        else:
            y.append(i)
    return sorted(x)+sorted(y)

print(order(["xylo", "xylophone", "xyz", "xy", "mango", "apple", "orange", "google"]))
# Out:
# ['xy', 'xylo', 'xylophone', 'xyz', 'apple', 'google', 'mango', 'orange']

# %%
# Given a list of non-empty tuples, return a list sorted in increasing order by the last element in each tuple.

def sort_last(list):
    for i in range(len(list)):
        for j in range(len(list)-1):
            if list[j][-1]>list[j+1][-1]:
                list[j],list[j+1] = list[j+1],list[j]
    return list

# %%
print(sort_last([(8,9),(2,11),(4,5),(10,1),(6,7)]))
# Out:
# [(10, 1), (4, 5), (6, 7), (8, 9), (2, 11)]

# %%
# Given a list of numbers, return a list where all adjacent == elements have been reduced to a single element, so [1, 2, 2, 3] returns [1, 2, 3].

def remove(nums):
    for i in range(len(nums)-2):
        if nums[i]==nums[i+1]:
            nums.pop(i+1)
    return nums

# %%
print(remove([1, 2, 2, 3]))
# Out:
# [1, 2, 3]

# %%
# two lists sorted in increasing order, create and return a merged list of all the elements in sorted order

def merge(list1,list2):
    return sorted(list1+list2)

print(merge([4,5,6],[1,2,3]))
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
import pandas as pd
df = pd.read_csv("drinks.csv")
df
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# ...

# %%
# Find the rows in the dataset
df.shape
# Out:
# (193, 6)

# %%
df.isna().sum()
# Out:
# country                          0
# beer_servings                    0
# spirit_servings                  0
# wine_servings                    0
# total_litres_of_pure_alcohol     0
# continent                       23
# dtype: int64

# %%
# Drop na values
df.dropna(inplace=True)
df.isna().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %%
# A function that takes name of the coloumn and outputs the data in the column
def col_data(col_name):
    return df[col_name]

print(col_data("wine_servings"))
# Out:
# 0        0
# 1       54
# 2       14
# 3      312
# 4       45
#       ...
# 188      3
# 189      1
# 190      0
# 191      4
# 192      4
# Name: wine_servings, Length: 170, dtype: int64

# %%
# Plot histograms of data
import matplotlib.pyplot as plt
df.hist(column="beer_servings")
# Out:
# array([[<AxesSubplot:title={'center':'beer_servings'}>]], dtype=object)

# %%
from tkinter import PROJECTING
df.plot(kind="scatter",x="beer_servings",y="wine_servings", s=6, c='green',marker="o")
# Out:
# <AxesSubplot:xlabel='beer_servings', ylabel='wine_servings'>

# %%
from mpl_toolkits.mplot3d import Axes3D
# plot a 3d graph
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(df["beer_servings"],df["spirit_servings"],df["wine_servings"])
plt.show()
# Out:
# C:\Users\Amina Bibi\AppData\Local\Temp\ipykernel_640\4001481681.py:4: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
# Plot a pie 
df.plot(kind="pie",y="beer_servings",figsize=(10,10),autopct="%1.1f%%",shadow=True,startangle=90)
# Out:
# <AxesSubplot:ylabel='beer_servings'>

# %%
# Plot bar chart
df.plot(kind="bar",y="beer_servings",figsize=(10,10),legend=True)
# Out:
# <AxesSubplot:>
